# %%
import pandas as pd 
from sklearn.linear_model import LogisticRegression

# %%
df = pd.read_csv('train_data.txt', sep=':::', engine='python', header=None)

# %%
# df = pd.read_csv(df, sep=r'\s*%:::\s*%', engine='python', header=None)
print(df)
# Out:
#            0                                             1              2  \
# 0          1                 Oscar et la dame rose (2009)          drama
# 1          2                                 Cupid (1997)       thriller
# 2          3             Young, Wild and Wonderful (1980)          adult
# 3          4                        The Secret Sin (1915)          drama
# 4          5                       The Unrecovered (2007)          drama
# ...      ...                                           ...            ...
# 54209  54210                              "Bonino" (1953)         comedy
# 54210  54211                  Dead Girls Don't Cry (????)         horror
# 54211  54212    Ronald Goedemondt: Ze bestaan echt (2008)    documentary
# 54212  54213                     Make Your Own Bed (1944)         comedy
# 54213  54214   Nature's Fury: Storm of the Century (2006)        history
#
#                                                        3
# ...

# %%
df.columns = ['id', 'name', 'genre', 'description']

# %%
df
# Out:
#           id                                          name          genre  \
# 0          1                 Oscar et la dame rose (2009)          drama
# 1          2                                 Cupid (1997)       thriller
# 2          3             Young, Wild and Wonderful (1980)          adult
# 3          4                        The Secret Sin (1915)          drama
# 4          5                       The Unrecovered (2007)          drama
# ...      ...                                           ...            ...
# 54209  54210                              "Bonino" (1953)         comedy
# 54210  54211                  Dead Girls Don't Cry (????)         horror
# 54211  54212    Ronald Goedemondt: Ze bestaan echt (2008)    documentary
# 54212  54213                     Make Your Own Bed (1944)         comedy
# 54213  54214   Nature's Fury: Storm of the Century (2006)        history
#
#                                              description  year
# ...

# %%
df['year'] = df['name'].str.extract(r'\((\d{4})\)')

# %%
df.sample(2)
# Out:
#           id                      name     genre  \
# 30923  30924          Amoklauf (1994)    horror
# 30637  30638   Gong fu xiao zi (1977)    action
#
#                                              description  year
# 30923   Excerpts of the life of a waiter who, living ...  1994
# 30637   He's lost his memory, but not his skill: Afte...  1977

# %%
## This line removes given year and also removes this "(????)" 

df['name'] = df['name'].str.replace(r'\s*\((\d{4}|\?{4})\)', '', regex=True)

# %%
df['year'] = pd.to_datetime(df['year'], format='%Y')

# %%
df.sample(2)
# Out:
#           id                       name          genre  \
# 52067  52068   Meeting at the Building          short
# 9860    9861           Zulu Meets Jazz    documentary
#
#                                              description       year
# 52067   It's a summer morning at the Building 111 of ... 2012-01-01
# 9860    ZULU meets JAZZ provides an opportunity to le... 2008-01-01

# %%
# Out:
# (49867, 5)
